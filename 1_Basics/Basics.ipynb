# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\ERKAN\\Downloads\\data_jobs.csv")
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df[["job_title_short", "job_location"]].head(100)
# Out:
#          job_title_short                  job_location
# 0   Senior Data Engineer                 Watertown, CT
# 1           Data Analyst  Guadalajara, Jalisco, Mexico
# 2          Data Engineer               Berlin, Germany
# 3          Data Engineer               San Antonio, TX
# 4          Data Engineer                Washington, DC
# ..                   ...                           ...
# 95         Data Engineer    Mumbai, Maharashtra, India
# 96         Data Engineer                  Torrance, CA
# 97          Data Analyst                United Kingdom
# 98  Senior Data Engineer           Toronto, ON, Canada
# 99         Data Engineer                     Miami, FL
#
# [100 rows x 2 columns]

# %%
df.iloc[90:100]
# Out:
#          job_title_short                                          job_title  \
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...
#
#                   job_location                         job_via  \
# 90                   Australia             via BeBee Australia
# ...

# %%
df.iloc[90:100, 0:2]
# Out:
#          job_title_short                                          job_title
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...

# %%
df[["job_title_short", "job_location"]].iloc[90:100]
# Out:
#          job_title_short                job_location
# 90        Data Scientist                   Australia
# 91        Data Scientist               Temuco, Chile
# 92         Data Engineer                    Anywhere
# 93          Data Analyst                    Anywhere
# 94         Data Engineer                    Lehi, UT
# 95         Data Engineer  Mumbai, Maharashtra, India
# 96         Data Engineer                Torrance, CA
# 97          Data Analyst              United Kingdom
# 98  Senior Data Engineer         Toronto, ON, Canada
# 99         Data Engineer                   Miami, FL

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
df["job_title_short"].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df["job_title_short"] == "Data Analyst"
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737     True
# 785738    False
# 785739    False
# 785740    False
# Name: job_title_short, Length: 785741, dtype: bool

# %%
df[df["job_title_short"] == "Data Analyst"]
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df[ (df.job_title_short == "Data Analyst") & (df.salary_year_avg > 100000) ]
# Out:
#        job_title_short                                      job_title  \
# 410       Data Analyst    IT Business Lead Data Analyst - VP - Hybrid
# 1555      Data Analyst                  Data Analyst/Engineer (M/F/D)
# 1681      Data Analyst                                   Data Analyst
# 1684      Data Analyst                       Data Analyst - Data17829
# 1867      Data Analyst  Data Integration Analyst (West Coast/Chicago)
# ...                ...                                            ...
# 783588    Data Analyst                         Data Analytics Manager
# 783866    Data Analyst                Lead Credit Bureau Data Analyst
# 784033    Data Analyst                       Recruitment Data Analyst
# 785187    Data Analyst                                   Data Analyst
# 785515    Data Analyst                                   Data Analyst
#
#                        job_location               job_via job_schedule_type  \
# ...

# %%
df.salary_year_avg.notna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: salary_year_avg, Length: 785741, dtype: bool

# %%
df2 = df.filter(["job_location"])
df2
# Out:
#                                job_location
# 0                             Watertown, CT
# 1              Guadalajara, Jalisco, Mexico
# 2                           Berlin, Germany
# 3                           San Antonio, TX
# 4                            Washington, DC
# ...                                     ...
# 785736                            Singapura
# 785737                   Bad Rodach, Jerman
# 785738                             Malaysia
# 785739  Newark, New Jersey, Amerika Serikat
# 785740                                India
#
# [785741 rows x 1 columns]

# %%
filt = (df.job_country == "United States")
df[filt]
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
df.loc[filt]
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
df.loc[filt, "job_title"]
# Out:
# 0         Senior Clinical Data Engineer / Principal Clin...
# 3         LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                         GCP Data Engineer
# 6                         Senior Data Engineer  - GCP Cloud
# 9                                         Data Scientist II
#                                 ...
# 785673                      Asset Management Data Scientist
# 785685                                         Data Analyst
# 785692                 Data Scientist- Hybrid Work Location
# 785703              Data Analyst - CRYPTOGRAPHY - Full-time
# 785705            Expert Business Data Analyst - Now Hiring
# Name: job_title, Length: 206292, dtype: object

# %%
filt2 = (df.job_title == "Data Analyst") & (df.job_health_insurance == True)
df[filt2].head(8)
# Out:
#      job_title_short     job_title              job_location  \
# 36      Data Analyst  Data Analyst            Des Moines, IA
# 385     Data Analyst  Data Analyst              Waukesha, WI
# 476     Data Analyst  Data Analyst             St Peters, MO
# 587     Data Analyst  Data Analyst            Fort Worth, TX
# 1169    Data Analyst  Data Analyst             Cupertino, CA
# 1276    Data Analyst  Data Analyst  Suitland-Silver Hill, MD
# 1291    Data Analyst  Data Analyst             Palo Alto, CA
# 1663    Data Analyst  Data Analyst                 Chico, CA
#
#                    job_via job_schedule_type  job_work_from_home  \
# 36         via Trabajo.org         Full-time               False
# 385        via Trabajo.org         Full-time               False
# 476        via Trabajo.org         Full-time               False
# 587             via Indeed         Full-time               False
# 1169             via BeBee         Full-time               False
# ...

# %%
df.loc[filt2, "job_title_short"].tail(8)
# Out:
# 781409    Data Analyst
# 781526    Data Analyst
# 782119    Data Analyst
# 782688    Data Analyst
# 783604    Data Analyst
# 784619    Data Analyst
# 784929    Data Analyst
# 785539    Data Analyst
# Name: job_title_short, dtype: object

# %%
filter3 = df.salary_year_avg.notna() & ( (df.job_country == "United States") | (df.salary_year_avg > 120_000) )
df.loc[filter3, ["job_title_short", "salary_year_avg"]]
# Out:
#        job_title_short  salary_year_avg
# 77       Data Engineer         140000.0
# 92       Data Engineer         120000.0
# 100     Data Scientist         228222.0
# 109       Data Analyst          89000.0
# 116     Data Scientist         114000.0
# ...                ...              ...
# 785624   Data Engineer         139216.0
# 785641   Data Engineer         150000.0
# 785648  Data Scientist         221875.0
# 785682  Data Scientist         157500.0
# 785692  Data Scientist         157500.0
#
# [18361 rows x 2 columns]

# %%
# Öncelikle NaN olmayan salary_year_avg değerlerini filtreleyelim
notna_filter = df.salary_year_avg.notna()

# Daha sonra diğer filtreleri uygulayalım
filter3 = notna_filter & ((df.job_country == "United States") | (df.salary_year_avg > 120_000))

# Sonuçları gösterelim
df.loc[filter3, ["job_title_short", "salary_year_avg"]]
# Out:
#        job_title_short  salary_year_avg
# 77       Data Engineer         140000.0
# 92       Data Engineer         120000.0
# 100     Data Scientist         228222.0
# 109       Data Analyst          89000.0
# 116     Data Scientist         114000.0
# ...                ...              ...
# 785624   Data Engineer         139216.0
# 785641   Data Engineer         150000.0
# 785648  Data Scientist         221875.0
# 785682  Data Scientist         157500.0
# 785692  Data Scientist         157500.0
#
# [18361 rows x 2 columns]

# %%
df[filt].head(8)
# Out:
#          job_title_short                                          job_title  \
# 0   Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 3          Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5          Data Engineer                                  GCP Data Engineer
# 6   Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 9         Data Scientist                                  Data Scientist II
# 11         Data Engineer                                      Data Engineer
# 13  Senior Data Engineer                               Senior Data Engineer
# 17        Data Scientist                             Data Science Team Lead
#
#                           job_location  \
# 0                        Watertown, CT
# 3                      San Antonio, TX
# 5                             Anywhere
# 6                         Dearborn, MI
# 9                             Anywhere
# 11  Colorado Springs, CO   (+3 others)
# ...

# %%
df.loc[~filt, "job_country"].head(12)
# Out:
# 1             Mexico
# 2            Germany
# 4              Sudan
# 7            Romania
# 8            Denmark
# 10       Switzerland
# 12            France
# 14            Brazil
# 15    United Kingdom
# 16             India
# 18            Poland
# 19             India
# Name: job_country, dtype: object

# %%
countries = ["United States", "Portugal", "India"]
filt = df.job_country.isin(countries)
df.loc[filt, "job_country"].tail(20)
# Out:
# 785641    United States
# 785645            India
# 785648    United States
# 785651    United States
# 785654            India
# 785673    United States
# 785674            India
# 785684            India
# 785685    United States
# 785691            India
# 785692    United States
# 785695            India
# 785697            India
# 785703    United States
# 785705    United States
# 785712            India
# 785715            India
# 785716            India
# 785718            India
# 785740            India
# Name: job_country, dtype: object

# %%
filt = df.job_skills.str.contains("python", na=False)
df.loc[filt, "job_skills"]
# Out:
# 1         ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2         ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3         ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4         ['bash', 'python', 'oracle', 'aws', 'ansible',...
# 5                                  ['python', 'sql', 'gcp']
#                                 ...
# 785731    ['nosql', 'mongodb', 'mongodb', 'python', 'ela...
# 785732    ['python', 'c#', 'java', 'scala', 'sql', 'post...
# 785735    ['sql', 'python', 'bigquery', 'aws', 'airflow'...
# 785736    ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785739    ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# Name: job_skills, Length: 380909, dtype: object

# %%
df.job_posted_date[0]
# Out:
# '2023-06-16 13:44:15'

# %%
type(df.job_posted_date[0])
# Out:
# str

# %%
pd.to_datetime(df.job_posted_date)
# Out:
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 785736   2023-03-13 06:16:16
# 785737   2023-03-12 06:18:18
# 785738   2023-03-12 06:32:36
# 785739   2023-03-12 06:32:15
# 785740   2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df["job_posted_date"] = pd.to_datetime(df.job_posted_date)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_posted_date.dt.month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int64

# %%
df["job_posted_month"] = df.job_posted_date.dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
pd.set_option('display.max_colwidth', None)
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                                    job_title  \
# 0       Senior Clinical Data Engineer / Principal Clinical Data Engineer ...
# 1                                                               Data Analyst
# 2                     Data Engineer/Scientist/Analyst, Mid or Senior (m/f/x)
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ENGINEER -  DATA...
# 4                                                     Data Engineer- Sr Jobs
# ...                                                                      ...
# ...

# %%
df.sort_values("job_posted_date")
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                         job_title  \
# 108804                                               Data Analyst
# 96906                                                Data Analyst
# 98438                                                Data Analyst
# 110290                                               Data Analyst
# 72158                   Senior Data Analyst / Platform Experience
# ...                                                           ...
# 362129                                              Data engineer
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                                    job_title  \
# 0       Senior Clinical Data Engineer / Principal Clinical Data Engineer ...
# 1                                                               Data Analyst
# 2                     Data Engineer/Scientist/Analyst, Mid or Senior (m/f/x)
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ENGINEER -  DATA...
# 4                                                     Data Engineer- Sr Jobs
# ...                                                                      ...
# ...

# %%
df.sort_values("job_posted_date", inplace= True)

# %%
df
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                         job_title  \
# 108804                                               Data Analyst
# 96906                                                Data Analyst
# 98438                                                Data Analyst
# 110290                                               Data Analyst
# 72158                   Senior Data Analyst / Platform Experience
# ...                                                           ...
# 362129                                              Data engineer
# ...

# %%
filt = df.salary_hour_avg.notna()
final_value = df.loc[filt, ["salary_hour_avg", "job_title"]]

# %%
final_value.iloc[90:150]
# Out:
#         salary_hour_avg  \
# 459647        24.000000
# 471808        24.000000
# 482191        24.000000
# 4794          24.000000
# 476221        24.000000
# 469771        24.000000
# 18910         24.000000
# 476737        24.000000
# 482177        24.000000
# 468245        24.000000
# 453610        24.000000
# 481032        24.000000
# 463680        24.000000
# 453527        24.000000
# 459298        24.000000
# 472696        24.000000
# 447005        24.000000
# 456619        24.000000
# 472853        24.000000
# 461473        24.000000
# 476715        24.000000
# 475187        24.000000
# 449420        24.000000
# 463622        24.000000
# 480801        24.000000
# 473000        24.000000
# 472238        24.000000
# 475977        24.000000
# 449532        24.000000
# 468171        24.000000
# 467959        24.000000
# 480015        24.000000
# 468989        24.000000
# 458093        24.000000
# 466270        24.000000
# 486069        24.000000
# 448571        24.000000
# ...

# %%
df2= pd.read_csv("C:\\Users\\ERKAN\\Downloads\\data_jobs.csv")
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df2.drop(labels="salary_hour_avg", axis=1, inplace=True)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785727 non-null  object
# ...

# %%
df.dropna(subset=["salary_year_avg"], inplace=True)
df
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 334082          Data Engineer
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# ...                       ...
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
# 336301         Data Scientist
# 327439          Data Engineer
#
#                                                       job_title  \
# 108883                                           Data Scientist
# 334082                                            Data Engineer
# 365786                           Hospitality Operations Analyst
# 366073                              Data Analytics Professional
# 108099                             Lead Data Scientist (Hybrid)
# ...                                                         ...
# 186163  Tech Lead / Sr Data Scientist, Product Analytics - USDS
# 421728                                Data Analyst - Operations
# ...

# %%
df = pd.read_csv("C:\\Users\\ERKAN\\Downloads\\data_jobs.csv")
df["job_posted_date"] = pd.to_datetime(df.job_posted_date)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
df.count()
# Out:
# job_title_short          785741
# job_title                785740
# job_location             784696
# job_via                  785733
# job_schedule_type        773074
# job_work_from_home       785741
# search_location          785741
# job_posted_date          785741
# job_no_degree_mention    785741
# job_health_insurance     785741
# job_country              785692
# salary_rate               33067
# salary_year_avg           22003
# salary_hour_avg           10662
# company_name             785727
# job_skills               668704
# job_type_skills          668704
# dtype: int64

# %%
mean_salary = df.salary_year_avg.mean()

# %%
formatted_mean = f"{mean_salary:.2f}"
print(formatted_mean)
# Out:
# 123286.27

# %%
df.salary_year_avg.min()
# Out:
# 15000.0

# %%
min_salary = df.salary_year_avg.idxmin()
df.iloc[min_salary]
# Out:
# job_title_short                                                                                                                                            Data Engineer
# job_title                                                                                                                                         Data Engineer - Hadoop
# job_location                                                                                                                                                      Brazil
# job_via                                                                                                                                                     via LinkedIn
# job_schedule_type                                                                                                                                              Full-time
# ...

# %%
df.job_title_short.value_counts()
# Out:
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: job_title_short, dtype: int64

# %%
df.groupby("job_title_short")["salary_year_avg"].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby("job_title_short")["salary_year_avg"].mean()
# Out:
# job_title_short
# Business Analyst              91082.612833
# Cloud Engineer               111268.453846
# Data Analyst                  93841.907854
# Data Engineer                130125.604250
# Data Scientist               135988.837171
# Machine Learning Engineer    126774.315972
# Senior Data Analyst          113911.363665
# Senior Data Engineer         145840.611624
# Senior Data Scientist        154206.292996
# Software Engineer            113393.760054
# Name: salary_year_avg, dtype: float64

# %%
df.groupby( ["job_title_short", "job_country"] )["salary_year_avg"].mean()
# Out:
# job_title_short    job_country
# Business Analyst   Afghanistan        NaN
#                    Albania            NaN
#                    Algeria            NaN
#                    Angola             NaN
#                    Argentina      71100.0
#                                    ...
# Software Engineer  Venezuela          NaN
#                    Vietnam        53600.0
#                    Yemen              NaN
#                    Zambia             NaN
#                    Zimbabwe           NaN
# Name: salary_year_avg, Length: 1387, dtype: float64

# %%
df.dropna(subset=["salary_year_avg"])
df.groupby( ["job_title_short", "job_country"] )["salary_year_avg"].mean()
# Out:
# job_title_short    job_country
# Business Analyst   Argentina                71100.000000
#                    Australia                87666.666667
#                    Bangladesh               16500.000000
#                    Belgium                  82620.000000
#                    Bulgaria                 73987.500000
#                                                ...
# Software Engineer  Ukraine                  54000.000000
#                    United Arab Emirates     79200.000000
#                    United Kingdom          103280.000000
#                    United States           137964.929588
#                    Vietnam                  53600.000000
# Name: salary_year_avg, Length: 598, dtype: float64

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000              0.0
# mean     123286.274072              NaN
# std       48312.449482              NaN
# min       15000.000000              NaN
# 25%       90000.000000              NaN
# 50%      115000.000000              NaN
# 75%      150000.000000              NaN
# max      960000.000000              NaN

# %%
df= pd.read_csv("C:\\Users\\ERKAN\\Downloads\\data_jobs.csv")
df.dropna(subset=["salary_hour_avg"])
df.dropna(subset=["salary_year_avg"])
df.groupby("job_title_short")[["salary_year_avg", "salary_hour_avg"]].mean()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst              91082.612833        42.723415
# Cloud Engineer               111268.453846        45.560715
# Data Analyst                  93841.907854        38.106918
# Data Engineer                130125.604250        57.196998
# Data Scientist               135988.837171        49.361403
# Machine Learning Engineer    126774.315972        48.477935
# Senior Data Analyst          113911.363665        47.661218
# Senior Data Engineer         145840.611624        62.848496
# Senior Data Scientist        154206.292996        54.105631
# Software Engineer            113393.760054        46.452019

# %%
df.groupby("job_title_short")["salary_year_avg"].agg(["min", "max", "mean"])
# Out:
#                                min       max           mean
# job_title_short
# Business Analyst           16500.0  387460.0   91082.612833
# Cloud Engineer             42000.0  280000.0  111268.453846
# Data Analyst               25000.0  650000.0   93841.907854
# Data Engineer              15000.0  525000.0  130125.604250
# Data Scientist             27000.0  960000.0  135988.837171
# Machine Learning Engineer  30000.0  325000.0  126774.315972
# Senior Data Analyst        30000.0  425000.0  113911.363665
# Senior Data Engineer       35000.0  425000.0  145840.611624
# Senior Data Scientist      45000.0  890000.0  154206.292996
# Software Engineer          28000.0  375000.0  113393.760054

# %%
import pandas as pd
df3= pd.read_csv("C:\\Users\\ERKAN\\Downloads\\data_jobs.csv")
us_jobs= df3[df3.job_country == "United States"]
us_jobs.groupby("job_title_short")["salary_year_avg"].agg(["median", "min", "max", "count"]).sort_values("median", ascending=False)
# Out:
#                              median      min       max  count
# job_title_short
# Senior Data Scientist      155000.0  55000.0  475000.0   1241
# Machine Learning Engineer  150000.0  44408.5  315000.0    128
# Senior Data Engineer       150000.0  45000.0  375000.0   1058
# Data Scientist             130000.0  30000.0  960000.0   4553
# Software Engineer          130000.0  48982.0  375000.0    157
# Data Engineer              125000.0  23496.0  525000.0   2915
# Cloud Engineer             116100.0  42000.0  221844.0     20
# Senior Data Analyst        110000.0  35360.0  425000.0    913
# Business Analyst            90000.0  35000.0  387460.0    431
# Data Analyst                90000.0  25000.0  375000.0   4350

# %%
df3["job_country"].isin(["Brazil"])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: job_country, Length: 785741, dtype: bool

# %%
df3["job_country"].isin(["Brazil"]).any()
# Out:
# True

# %%
us_jobs = df3[(df3.job_country == "United States") & 
              df3.salary_year_avg.notna() & 
              df3.salary_hour_avg.notna()]
us_jobs.groupby("job_title_short")[["salary_year_avg", "salary_hour_avg"]].mean()
# Out:
# Empty DataFrame
# Columns: [salary_year_avg, salary_hour_avg]
# Index: []

# %%
us_jobs.groupby("job_title_short")[["salary_year_avg", "salary_hour_avg"]].min()
# Out:
# Empty DataFrame
# Columns: [salary_year_avg, salary_hour_avg]
# Index: []

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("C:\\Users\\ERKAN\\Downloads\\data_jobs.csv")
df.job_posted_date = pd.to_datetime(df.job_posted_date)

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x,y)

# %%
x = [2,4,6,8]
y = [1,2,3,4]
plt.plot(x,y)
plt.show()

# %%
df.job_posted_date.head()
# Out:
# 0   2023-06-16 13:44:15
# 1   2023-01-14 13:18:07
# 2   2023-10-10 13:14:55
# 3   2023-07-04 13:01:41
# 4   2023-08-07 14:29:36
# Name: job_posted_date, dtype: datetime64[ns]

# %%
date_counts = df.job_posted_date.value_counts()
date_counts
# Out:
# 2023-12-08 07:24:37    10
# 2023-01-08 00:19:57    10
# 2023-09-17 00:28:49    10
# 2023-09-07 00:07:24    10
# 2023-07-22 07:25:54    10
#                        ..
# 2023-05-17 17:27:41     1
# 2023-05-28 17:51:07     1
# 2023-09-05 17:10:27     1
# 2023-09-02 17:02:18     1
# 2023-03-12 06:32:36     1
# Name: job_posted_date, Length: 607192, dtype: int64

# %%
df["job_posted_month"] = df.job_posted_date.dt.month
df.job_posted_month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_month, Length: 785741, dtype: int64

# %%
month_counts = df.job_posted_month.value_counts()
month_counts
# Out:
# 1     91822
# 8     75162
# 10    66611
# 2     64578
# 11    64450
# 3     64084
# 7     63777
# 4     62919
# 9     62359
# 6     61572
# 12    56303
# 5     52104
# Name: job_posted_month, dtype: int64

# %%
month_counts =  month_counts.sort_index()
month_counts
# Out:
# 1     91822
# 2     64578
# 3     64084
# 4     62919
# 5     52104
# 6     61572
# 7     63777
# 8     75162
# 9     62359
# 10    66611
# 11    64450
# 12    56303
# Name: job_posted_month, dtype: int64

# %%
df.job_posted_date = pd.to_datetime(df.job_posted_date)
month_count = df.job_posted_date.dt.month
month_count = month_count.value_counts()
month_count = month_count.sort_index()
plt.plot(month_count.index, month_count.values)

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series([1,2,3], index=["a", "b", "c"])
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
series = pd.Series([1,2,3], index=["a", "b", "c"])
series.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
series.values
# Out:
# array([1, 2, 3], dtype=int64)

# %%
jobs = df.job_title_short.value_counts()
jobs
# Out:
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: job_title_short, dtype: int64

# %%
jobs = jobs.sort_values(ascending=False)
plt.bar(jobs.index, jobs.values)
plt.title("Jobs")
plt.xlabel("Job Posts")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
jobs = jobs.sort_values(ascending=False)
plt.bar(jobs.index, jobs.values)
plt.title("Jobs")
plt.xlabel("Job Posts")
plt.ylabel("Value")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
plt.barh(jobs.index, jobs.values)
# Out:
# <BarContainer object of 10 artists>

# %%
jobs = df.job_title_short.value_counts()
jobs = jobs.sort_values(ascending=False)
plt.barh(jobs.index, jobs.values)
# Out:
# <BarContainer object of 10 artists>

# %%
jobs.plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
jobs.plot(kind='bar')
plt.xlabel('')
plt.ylabel('Count of Postings')
plt.title('Job Postings by Job Title')
plt.xticks(rotation=45, ha='right') 
plt.show()

# %%
df[["job_posted_date", "salary_year_avg"]].dropna(subset=["salary_year_avg"])
# Out:
#            job_posted_date  salary_year_avg
# 28     2023-08-01 13:37:57         109500.0
# 77     2023-06-26 14:22:54         140000.0
# 92     2023-02-21 13:29:59         120000.0
# 100    2023-07-31 13:01:18         228222.0
# 109    2023-10-12 13:02:19          89000.0
# ...                    ...              ...
# 785624 2023-08-31 06:02:16         139216.0
# 785641 2023-01-04 16:36:07         150000.0
# 785648 2023-04-12 06:02:51         221875.0
# 785682 2023-03-04 06:16:08         157500.0
# 785692 2023-04-21 06:02:31         157500.0
#
# [22003 rows x 2 columns]

# %%
df.plot(x="job_posted_date", y="salary_year_avg", kind="line")
# Out:
# <AxesSubplot:xlabel='job_posted_date'>

# %%
job_salary = df.groupby("job_title_short")["salary_year_avg"].median().sort_values(ascending=False)
job_salary
# Out:
# job_title_short
# Senior Data Scientist        155500.0
# Senior Data Engineer         147500.0
# Data Scientist               127500.0
# Data Engineer                125000.0
# Senior Data Analyst          111175.0
# Machine Learning Engineer    106415.0
# Software Engineer             99150.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Business Analyst              85000.0
# Name: salary_year_avg, dtype: float64

# %%
type(job_salary)
# Out:
# pandas.core.series.Series

# %%
job_salary.plot(kind="barh")
plt.xlabel("Salary in USD($)")
plt.ylabel("")
plt.title("Median Salary By Jobs")
# Out:
# Text(0.5, 1.0, 'Median Salary By Jobs')

# %%
# Define data science job roles and required skills
job_roles = [
    {'role': 'Data Analyst', 'skills': ['Python', 'SQL', 'Data Visualization']},
    {'role': 'Data Engineer', 'skills': ['Python', 'SQL', 'Snowflake']},
    {'role': 'Data Scientist', 'skills': ['Python', 'Machine Learning', 'Statistics']}
]

# My skills
my_skills = ['Python', 'SQL', 'Data Visualization', 'Snowflake']


def is_qualified(job_skills, my_skills):
    return all(skill in my_skills for skill in job_skills)

qualified_roles = list(filter(lambda job: is_qualified(job['skills'], my_skills), job_roles))

qualified_role_titles = [job['role'] for job in qualified_roles]

if qualified_role_titles:
    output_message = 'I am potentially qualified for the following roles: ' + ', '.join(qualified_role_titles)
    print(output_message)
else:
    print('There are no matching job roles for my skills.')
# Out:
# I am potentially qualified for the following roles: Data Analyst, Data Engineer
