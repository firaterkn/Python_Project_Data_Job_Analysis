# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("C:\\Users\\ERKAN\\Downloads\\data_jobs.csv")
df["job_posted_date"] = pd.to_datetime(df.job_posted_date)

# %%
#random 7 elements in the table
df.sample(7)
# Out:
#          job_title_short                                          job_title  \
# 350098     Data Engineer     Big Data Management Informatica (BDM) Engineer
# 619299  Business Analyst                                  Reporting Analyst
# 629125  Business Analyst                                   Business Analyst
# 120697    Data Scientist                        Mid Data Scientist (Hybrid)
# 710469    Data Scientist            Senior Analytics Engineer Jobs In Ajman
# 21295       Data Analyst  Data Analyst(Hybrid - Atlanta,GA, W2 candidate...
# 269955  Business Analyst                         Riser et Pipeline Engineer
#
#                         job_location             job_via job_schedule_type  \
# 350098           Riyadh Saudi Arabia        via Bayt.com         Full-time
# 619299                       Belgium  via BeBee Belgique         Full-time
# 629125                   Oshkosh, WI          via Indeed         Full-time
# ...

# %%
df_duplicate = df
id(df) == id(df_duplicate)
# Out:
# True

# %%
df_copy = df.copy()
id(df) == id(df_copy)
# Out:
# False

# %%
year_avg = df.salary_year_avg.median()
hour_avg = df.salary_hour_avg.median()


df_copy.salary_year_avg = df_copy.salary_year_avg.fillna(year_avg)
df_copy.salary_hour_avg = df_copy.salary_hour_avg.fillna(hour_avg)

df_copy.loc[0:10, ["salary_year_avg", "salary_hour_avg"]]
# Out:
#     salary_year_avg  salary_hour_avg
# 0          115000.0            45.98
# 1          115000.0            45.98
# 2          115000.0            45.98
# 3          115000.0            45.98
# 4          115000.0            45.98
# 5          115000.0            45.98
# 6          115000.0            45.98
# 7          115000.0            45.98
# 8          115000.0            45.98
# 9          115000.0            45.98
# 10         115000.0            45.98

# %%
#original table didn't change
df.loc[0:10, ["salary_year_avg", "salary_hour_avg"]]
# Out:
#     salary_year_avg  salary_hour_avg
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# 5               NaN              NaN
# 6               NaN              NaN
# 7               NaN              NaN
# 8               NaN              NaN
# 9               NaN              NaN
# 10              NaN              NaN
