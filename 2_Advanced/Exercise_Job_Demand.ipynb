# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("C:\\Users\\ERKAN\\Downloads\\data_jobs.csv")
df["job_posted_date"] = pd.to_datetime(df.job_posted_date)

# %%
# Top 5 job posted countries
df.job_country.value_counts().head(5)
# Out:
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Name: job_country, dtype: int64

# %%
df_france = df[df.job_country == "France"].copy()
df_france
# Out:
#               job_title_short  \
# 12               Data Analyst
# 21             Data Scientist
# 22              Data Engineer
# 31               Data Analyst
# 49      Senior Data Scientist
# ...                       ...
# 785478           Data Analyst
# 785507          Data Engineer
# 785514           Data Analyst
# 785555          Data Engineer
# 785693  Senior Data Scientist
#
#                                                 job_title  \
# 12            Stagiaire Data Analyst (H/F) - Lyon (69006)
# 21      Stage - data scientist – génération ia de donn...
# 22          Data Engineer / Développeur·euse Big Data F/H
# 31                               Stage - Data Analyst F/H
# 49                                        Data Senior H/F
# ...                                                   ...
# 785478                          Business Data Analyst H/F
# 785507                                      Data engineer
# 785514  Chargé de projets commerciaux et data analyst H/F
# ...

# %%
df_france["job_posted_month"] = df_france.job_posted_date.dt.strftime("%B")
df_france
# Out:
#               job_title_short  \
# 12               Data Analyst
# 21             Data Scientist
# 22              Data Engineer
# 31               Data Analyst
# 49      Senior Data Scientist
# ...                       ...
# 785478           Data Analyst
# 785507          Data Engineer
# 785514           Data Analyst
# 785555          Data Engineer
# 785693  Senior Data Scientist
#
#                                                 job_title  \
# 12            Stagiaire Data Analyst (H/F) - Lyon (69006)
# 21      Stage - data scientist – génération ia de donn...
# 22          Data Engineer / Développeur·euse Big Data F/H
# 31                               Stage - Data Analyst F/H
# 49                                        Data Senior H/F
# ...                                                   ...
# 785478                          Business Data Analyst H/F
# 785507                                      Data engineer
# 785514  Chargé de projets commerciaux et data analyst H/F
# ...

# %%
df_france_pivot = df_france.pivot_table(index="job_posted_month", columns="job_title_short", aggfunc="size")
df_france_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                           66              21          1455
# August                          38              25           957
# December                        88              32           731
# February                        66              32          1556
# January                         39              22          1549
# July                            45              17          1107
# June                            33              20          1224
# March                           54              25          1546
# May                             47              10          1141
# November                       124              72           911
# October                         75              37           871
# September                       63              25           755
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_france_pivot.reset_index(inplace=True)
df_france_pivot["month_number"] = pd.to_datetime(df_france_pivot.job_posted_month, format="%B").dt.month
df_france_pivot.sort_values("month_number", inplace=True)
df_france_pivot.set_index("job_posted_month", inplace=True)
df_france_pivot.drop(columns="month_number", inplace=True)
df_france_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                         39              22          1549
# February                        66              32          1556
# March                           54              25          1546
# April                           66              21          1455
# May                             47              10          1141
# June                            33              20          1224
# July                            45              17          1107
# August                          38              25           957
# September                       63              25           755
# October                         75              37           871
# November                       124              72           911
# December                        88              32           731
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_france_pivot.plot(kind="line", figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='job_posted_month'>

# %%
top3= df_france.job_title_short.value_counts().head(3)
top3 = top3.index.to_list()

# %%
df_france_pivot[top3].plot(kind="line", figsize=(10,5))

plt.xlabel("")
plt.title('Monthly Job Postings for Top Data Jobs in France')
plt.xticks(rotation=45, ha="right")
plt.legend()
plt.show()

# %%
#easier way to order the months
df_france_2 = df[df.job_country == "France"].copy()
df_france_2["job_posted_month"] = df_france_2["job_posted_date"].dt.to_period("M")
df_france_2 = df_france_2.pivot_table(index="job_posted_month", columns="job_title_short", aggfunc="size")

df_france_2
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# 2023-01                         39              22          1549
# 2023-02                         66              32          1556
# 2023-03                         54              25          1546
# 2023-04                         66              21          1455
# 2023-05                         47              10          1141
# 2023-06                         33              20          1224
# 2023-07                         45              17          1107
# 2023-08                         38              25           957
# 2023-09                         63              25           755
# 2023-10                         75              37           871
# 2023-11                        124              72           911
# 2023-12                         88              32           731
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_france_2[top3].plot(kind="line", figsize=(10,5))

plt.xlabel("")
plt.title('Monthly Job Postings for Top Data Jobs in France')
plt.xticks(rotation=45, ha="right")
plt.legend()
plt.show()
